# %%
import numpy as np

from sklearn.datasets import load_iris

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
# Out:
# Running cells with '/bin/python3.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
iris = load_iris()

X_train, X_test, y_train, y_test = train_test_split(
	iris['data'], iris['target'], random_state=0)

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
pred_knn = knn.predict(X_test)
# Out:
# Running cells with '/bin/python3.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Test set accuracy: {:.2f}".format(knn.score(X_test, y_test)))

# %%
print("Treino", len(y_train))
print("Teste", len(y_test))

# %%
print("Sample counts per class:\n{}".format(
{n: v for n, v in zip(iris.target_names, np.bincount(iris.target))}))

# %% [markdown]
# 3- a) os parâmetros por omissão do train_test_split são train_size=None, test_size=None,random_state = None, shuffle=True,stratify=None, do KNeighboursClassifier são n_neighbours=5, weights = 'uniform', algorithm = 'auto', leaf_size = 30, p = 2, metric= 'minkowski', metric_params = None e n_jobs = None

# %% [markdown]
# Exatidão = 97%

# %%
b) O fit() faz o modelo aprender os dados.
c) predict faz uma previsão das instâncias dos dados de X_test, ou seja, novos dados são gerados a partir dos dados de teste.
